# %%
import tensorflow as tf 

fashion_mnist = tf.keras.datasets.fashion_mnist

(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
X_train, X_test = X_train / 255.0, X_test / 255.0
# Out:
# 2024-02-26 16:31:40.965728: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-02-26 16:31:40.996646: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-26 16:31:40.996677: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-26 16:31:40.997351: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-26 16:31:41.002516: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-26 16:31:41.736503: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import random
import matplotlib.pyplot as plt 
# %matplotlib inline 

samples = random.choices(population=range(0, len(y_train)), k = 16)

# %%
plt.figure(figsize = (14, 12))

for idx, n in enumerate(samples):
    plt.subplot(4, 4, idx+1)
    plt.imshow(X_train[n].reshape(28, 28), cmap = 'Greys', interpolation='nearest')
    plt.title('Label : ' + str(y_train[n]))
    plt.axis('off')


plt.show()

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape = (28, 28)),
    tf.keras.layers.Dense(1000, activation = 'relu'),
    tf.keras.layers.Dense(10, activation = 'softmax')
])

model.compile(optimizer = 'adam',
              loss = 'sparse_categorical_crossentropy',
              metrics = ['accuracy'])
# Out:
# 2024-02-26 16:31:43.749506: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-26 16:31:43.785706: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-26 16:31:43.785986: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-26 16:31:43.787206: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-26 16:31:43.787372: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-26 16:31:43.787449: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-26 16:31:43.838964: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-26 16:31:43.839078: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-26 16:31:43.839159: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-26 16:31:43.839229: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1171 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 1000)              785000
#
#  dense_1 (Dense)             (None, 10)                10010
#
# =================================================================
# Total params: 795010 (3.03 MB)
# Trainable params: 795010 (3.03 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
import time 

start_time = time.time()
hist = model.fit(X_train, y_train, validation_data = (X_test, y_test),
                 epochs = 10, batch_size = 100, verbose = 1 )

print('Fit time :', time.time() - start_time)
# Out:
# Epoch 1/10
# 2024-02-26 16:31:44.714271: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f224b1481b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-02-26 16:31:44.714287: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2024-02-26 16:31:44.718622: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-02-26 16:31:44.731579: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1708932704.789569    6499 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 600/600 [==============================] - 2s 3ms/step - loss: 0.4860 - accuracy: 0.8290 - val_loss: 0.4258 - val_accuracy: 0.8450
# Epoch 2/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.3607 - accuracy: 0.8689 - val_loss: 0.3736 - val_accuracy: 0.8665
# Epoch 3/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.3220 - accuracy: 0.8809 - val_loss: 0.3511 - val_accuracy: 0.8741
# Epoch 4/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2967 - accuracy: 0.8910 - val_loss: 0.3435 - val_accuracy: 0.8781
# Epoch 5/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2819 - accuracy: 0.8963 - val_loss: 0.3440 - val_accuracy: 0.8780
# Epoch 6/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2642 - accuracy: 0.9015 - val_loss: 0.3386 - val_accuracy: 0.8808
# Epoch 7/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2504 - accuracy: 0.9072 - val_loss: 0.3279 - val_accuracy: 0.8818
# Epoch 8/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2411 - accuracy: 0.9111 - val_loss: 0.3424 - val_accuracy: 0.8770
# Epoch 9/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2308 - accuracy: 0.9136 - val_loss: 0.3200 - val_accuracy: 0.8864
# Epoch 10/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2189 - accuracy: 0.9190 - val_loss: 0.3184 - val_accuracy: 0.8916
# Fit time : 14.412981748580933

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline 

plot_target = ['loss', 'val_loss', 'accuracy', 'val_accuracy']

plt.figure(figsize = (12, 8))

for each in plot_target:
    plt.plot(hist.history[each], label = each)

plt.legend()
plt.grid()

plt.show()

# %%
score = model.evaluate(X_test, y_test)
print('Test loss :', score[0])
print('Test accuracy :', score[1])
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.3184 - accuracy: 0.8916
# Test loss : 0.31835299730300903
# Test accuracy : 0.8916000127792358

# %%
import numpy as np 

predicted_result = model.predict(X_test)
predicted_labels = np.argmax(predicted_result, axis = 1)
predicted_labels[:10]
# Out:
# 313/313 [==============================] - 0s 898us/step
# array([9, 2, 1, 1, 6, 1, 4, 6, 5, 7])

# %%
y_test[:10]
# Out:
# array([9, 2, 1, 1, 6, 1, 4, 6, 5, 7], dtype=uint8)

# %%
wrong_result = []

for n in range(0, len(y_test)):
    if predicted_labels[n] != y_test[n]:
        wrong_result.append(n)

len(wrong_result)
# Out:
# 1084

# %%
import random

samples = random.choices(population = wrong_result, k = 16)
samples
# Out:
# [9601,
#  529,
#  5718,
#  2878,
#  3265,
#  985,
#  2476,
#  1494,
#  6020,
#  4995,
#  2447,
#  1643,
#  3720,
#  9398,
#  1586,
#  5934]

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline 

plt.figure(figsize = (14, 12))

for idx, n in enumerate(samples):
    plt.subplot(4, 4, idx+1)
    plt.imshow(X_test[n].reshape(28, 28), cmap = 'Greys', interpolation='nearest')
    plt.title('Label : ' + str(y_test[n]) + 'predict : ' + str(predicted_labels[n]))
    plt.axis('off')


plt.show()
